# %%
from math import log
import csv

f = open(r'/media/abysh/FAAA9688AA9640D5/pythonclass/git_project/Book1.csv','r')
data = list(csv.reader(f))
import numpy as np
data2 = np.array(data[1:],dtype=np.float)
datal=data2
rng=[i for i in range(len(data2))]       #rng=[0 to 69]
listt=[i for i in range(len(data[0])-1)] #listt=[0,1,2,3]
order_list=[]
print(np.array(data2[:,0].mean()))

def counting(data3,data4):
    count30=0
    count31=0
    count32=0
    count40=0
    count41=0
    count42=0
    for j in data3:
        if j[-1]==0:
            count30 +=1
        elif j[-1]==1:
            count31 +=1
        elif j[-1]==2:
            count32 +=1
    count3=[count30,count31,count32]
    for j in data4:
        if j[-1]==0:
            count40 +=1
        elif j[-1]==1:
            count41 +=1
        elif j[-1]==2:
            count42 +=1  
    count4=[count40,count41,count42]
    return (count3,count4)
print(len(data2[0]))

def find_entro(count3,count4):
    entro3=0
    entro4=0
    for x in count3:
        y=x/sum(count3)
        if y==0:
            entro3 +=1
        else:
            entro3 += -y*log(y,2)
    for x in count4:
        y=x/sum(count4)
        if y==0:
            entro4 +=1
        else:
            entro4 += -y*log(y,2) 
    return(entro3,entro4)

def find_order():
    while (len(listt)!=0):
        entro=[]
        for i in listt:
            b=(datal[:,i].mean())
            data3=np.array([d for d in datal if d[i]<b])
            data4=np.array([d for d in datal if d[i]>=b])

            count3,count4=counting(data3,data4)
            entro3,entro4=find_entro(count3,count4)

            entro.append(entro3+entro4)
        for i in range(len(listt)):
            if entro[i]==min(entro):
                q=i
                w=listt[i]
        order_list.append(w)
        listt.pop(q)
        for x in count3:
            if x==len(data3):
                datal.pop(data3)
        for x in count4:
            if x==len(data4):
                datal.pop(data4)
    print(order_list)   
    
find_order()
leafl=[]
c=1
o_list=order_list
leaf2=[]

def find_result(datam):
    for x in o_list:
        b=(datal[:,x].mean())
        if datam[x] 
        
        count3,count4=counting(data3,data4)
        if count3[0]==len(data3):
            leaf2.apend(1)
            leafl.append([c,"low"])
        elif count3[1]==len(data3):
            leaf2.append(1)
            leafl.append([c,"medium"])
        elif count3[2]==len(data3):
            leaf2.append(1)
            leafl.append([c,"high"])
        else:
            c+=1
            find_leaf()
        
        if count6[0]==len(data6):
            leafl=[1,"low"]
        elif count6[1]==len(data6):
            leafl=[1,"medium"]
        elif count6[2]==len(data6):
            leafl=[1,"high"]
        else:
# Out:
# 0.6872000000000001
# 5
# [3, 1, 0, 2]

# %%
_
